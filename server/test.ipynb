# %%
import requests
import asyncio
import json
import pandas as pd
from binance.spot import Spot
import json
import datetime
import time
from dotenv import load_dotenv
import os

load_dotenv("../.env")
# Out:
# True

# %%
BN_KEY = os.getenv('BN_KEY')
BN_SECRET = os.getenv('BN_SECRET')

# %%
from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager
from binance import AsyncClient, DepthCacheManager, BinanceSocketManager

client = Client(BN_KEY, BN_SECRET)

# %%
import nest_asyncio
nest_asyncio.apply()

async def main():
    client = await AsyncClient.create(BN_KEY, BN_SECRET)
    ret = await client.get_symbol_ticker(symbol="BTCUSDT")
    print(ret)
    print("\nxxx\n")
    print(json.dumps(ret, indent=4))


loop = asyncio.get_event_loop()
loop.run_until_complete(main())
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x12c26cf10>
# Unclosed connector
# connections: ['[(<aiohttp.client_proto.ResponseHandler object at 0x164b87d20>, 537451.640081)]']
# connector: <aiohttp.connector.TCPConnector object at 0x11fdc4fd0>
# {'symbol': 'BTCUSDT', 'price': '69485.57000000'}
#
# xxx
#
# {
#     "symbol": "BTCUSDT",
#     "price": "69485.57000000"
# }

# %%
client = await AsyncClient.create(BN_KEY, BN_SECRET)

# %%
#Get Dual Investment product list(USER_DATA)
# 获取可以投资列表
params = {
    "optionType": "CALL",  # PUT
    "exercisedCoin": "USDT",
    "investCoin": "BTC",
    "pageSize":100,
    "pageIndex":1
}
"""
params = {
    "optionType": "PUT",  
    "exercisedCoin": "BTC",
    "investCoin": "USDT"
}
"""
async def main():
    
    ret = await client._request_margin_api('get', '/dci/product/list', True, data=params)
    # print(ret)
    formatted = json.dumps(ret, indent=4)
    print(formatted)

asyncio.get_event_loop().run_until_complete(main())
# Out:
# {
#     "total": 507,
#     "list": [
#         {
#             "id": "959680",
#             "investCoin": "BTC",
#             "exercisedCoin": "USDT",
#             "strikePrice": "69750",
#             "duration": 6,
#             "settleDate": 1718352000000,
#             "purchaseDecimal": 8,
#             "purchaseEndTime": 1718265600000,
#             "canPurchase": true,
#             "apr": "0.7685",
#             "orderId": 14626659313,
#             "minAmount": "0.00001",
#             "maxAmount": "70",
#             "createTimestamp": 1715049775000,
#             "optionType": "CALL",
#             "isAutoCompoundEnable": true,
#             "autoCompoundPlanList": [
#                 "STANDARD",
#                 "ADVANCE"
#             ]
#         },
#         {
#             "id": "989035",
#             "investCoin": "BTC",
#             "exercisedCoin": "USDT",
#             "strikePrice": "70000",
#             "duration": 6,
#             "settleDate": 1718352000000,
#             "purchaseDecimal": 8,
#             "purchaseEndTime": 1718265600000,
#             "canPurchase": true,
#             "apr": "0.716",
#             "orderId": 14626722426,
#             "minAmount": "0.00001",
#             "maxAmount": "20",
#             "createTimestamp": 1716213511000,
#             "optionType": "CALL",
#             "isAutoCompoundEnable": true,
#             "autoCompoundPlanList": [
#                 "STANDARD",
#                 "ADVANCE"
#             ]
#         },
#         {
#             "id": "990401",
#             "investCoin": "BTC",
#             "exercisedCoin": "USDT",
#             "strikePrice": "70250",
#             "duration": 6,
#             "settleDate": 1718352000000,
#             "purchaseDecimal": 8,
#             "purchaseEndTime": 1718265600000,
#             "canPurchase": true,
#             "apr": "0.6104",
#             "orderId": 14615707979,
#             "minAmount": "0.00001",
#             "maxAmount": "70",
#             "createTimestamp": 1716213517000,
#             "optionType": "CALL",
#             "isAutoCompoundEnable": true,
#             "autoCompoundPlanList": [
#                 "STANDARD",
#                 "ADVANCE"
#             ]
#         },
#         {
#             "id": "959865",
#             "investCoin": "BTC",
#             "exercisedCoin": "USDT",
#             "strikePrice": "69750",
#             "duration": 13,
#             "settleDate": 1718956800000,
#             "purchaseDecimal": 8,
#             "purchaseEndTime": 1718870400000,
#             "canPurchase": true,
#             "apr": "0.6452",
#             "orderId": 14615708696,
#             "minAmount": "0.00001",
#             "maxAmount": "70",
#             "createTimestamp": 1715049883000,
#             "optionType": "CALL",
#             "isAutoCompoundEnable": true,
#             "autoCompoundPlanList": [
#                 "STANDARD",
#                 "ADVANCE"
#             ]
#         },
#         {
#             "id": "1019639",
#             "investCoin": "BTC",
#             "exercisedCoin": "USDT",
#             "strikePrice": "69750",
#             "duration": 3,
#             "settleDate": 1718092800000,
#             "purchaseDecimal": 8,
#             "purchaseEndTime": 1718006400000,
#             "canPurchase": true,
#             "apr": "0.6267",
#             "orderId": 14626721259,
#             "minAmount": "0.00001",
#             "maxAmount": "35",
#             "createTimestamp": 1716856423000,
#             "optionType": "CALL",
#             "isAutoCompoundEnable": true,
#             "autoCompoundPlanList": [
#                 "STANDARD",
#                 "ADVANCE"
#             ]
#         },
#         {
#             "id": "990643",
#             "investCoin": "BTC",
#             "exercisedCoin": "USDT",
#             "strikePrice": "70000",
#             "duration": 13,
#             "settleDate": 1718956800000,
#             "purchaseDecimal": 8,
#             "purchaseEndTime": 1718870400000,
#             "canPurchase": true,
#             "apr": "0.5989",
#             "orderId": 14626722440,
#             "minAmount": "0.00001",
#             "maxAmount": "20",
#             "createTimestamp": 1716213518000,
#             "optionType": "CALL",
#             "isAutoCompoundEnable": true,
#             "autoCompoundPlanList": [
#                 "STANDARD",
#                 "ADVANCE"
#             ]
#         },
#         {
#             "id": "988890",
#             "investCoin": "BTC",
#             "exercisedCoin": "USDT",
#             "strikePrice": "70500",
#             "duration": 6,
#             "settleDate": 1718352000000,
#             "purchaseDecimal": 8,
#             "purchaseEndTime": 1718265600000,
#             "canPurchase": true,
#             "apr": "0.5713",
#             "orderId": 14615707857,
#             "minAmount": "0.00001",
#             "maxAmount": "70",
#             "createTimestamp": 1716213511000,
#             "optionType": "CALL",
#             "isAutoCompoundEnable": true,
#             "autoCompoundPlanList": [
#                 "STANDARD",
#                 "ADVANCE"
#             ]
#         },
#         {
#             "id": "912136",
#             "investCoin": "BTC",
#             "exercisedCoin": "USDT",
#             "strikePrice": "69750",
#             "duration": 20,
#             "settleDate": 1719561600000,
#             "purchaseDecimal": 8,
#             "purchaseEndTime": 1719475200000,
#             "canPurchase": true,
#             "apr": "0.5707",
#             "orderId": 14615675402,
#             "minAmount": "0.00001",
#             "maxAmount": "70",
#             "createTimestamp": 1712650221000,
#             "optionType": "CALL",
#             "isAutoCompoundEnable": true,
#             "autoCompoundPlanList": [
#                 "STANDARD",
#                 "ADVANCE"
#             ]
#         },
#         {
#             "id": "991997",
#             "investCoin": "BTC",
#             "exercisedCoin": "USDT",
#             "strikePrice": "70250",
#             "duration": 13,
#             "settleDate": 1718956800000,
#             "purchaseDecimal": 8,
#             "purchaseEndTime": 1718870400000,
#             "canPurchase": true,
#             "apr": "0.5526",
#             "orderId": 14615709573,
#             "minAmount": "0.00001",
#             "maxAmount": "70",
#             "createTimestamp": 1716213526000,
#             "optionType": "CALL",
#             "isAutoCompoundEnable": true,
#             "autoCompoundPlanList": [
#                 "STANDARD",
#                 "ADVANCE"
#             ]
#         },
#         {
#             "id": "789250",
#             "investCoin": "BTC",
#             "exercisedCoin": "USDT",
#             "strikePrice": "70000",
#             "duration": 20,
#             "settleDate": 1719561600000,
#             "purchaseDecimal": 8,
#             "purchaseEndTime": 1719475200000,
#             "canPurchase": true,
#             "apr": "0.5465",
#             "orderId": 14626722466,
#             "minAmount": "0.00001",
#             "maxAmount": "20",
#             "createTimestamp": 1709788512000,
#             "optionType": "CALL",
#             "isAutoCompoundEnable": true,
#             "autoCompoundPlanList": [
#                 "STANDARD",
#                 "ADVANCE"
#             ]
#         }
#     ]
# }
